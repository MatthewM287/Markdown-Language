# %% [markdown]
# <a href="https://colab.research.google.com/github/MatthewM287/Markdown-Language/blob/main/Markdown_Language.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #I Will Tell You What I *Do* and **Don't** like

# %%
x = "I Like Sleeping"
y = "I Don't like working"
z = " and "
print( x + z + y)
# Out:
# I Like Sleeping and I Don't like working
